# %%
import xarray as xr
# Out:
# 2023.4.1

# %%
xr.open_mfdataset(r"D:\Factor-Data\Tesina\Tesina\New folder\*.nc", combine='nested',  chunks={'x': 50, 'y': 30, 'time': 1})
# Out:
# C:\Users\PC\.conda\envs\Tesina\lib\site-packages\xarray\core\indexing.py:1380: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   value = value[(slice(None),) * axis + (subkey,)]
# C:\Users\PC\.conda\envs\Tesina\lib\site-packages\dask\array\core.py:4832: PerformanceWarning: Increasing number of chunks by factor of 10
#   result = blockwise(
# C:\Users\PC\.conda\envs\Tesina\lib\site-packages\dask\array\core.py:4832: PerformanceWarning: Increasing number of chunks by factor of 43
#   result = blockwise(
# ...

# %%
a = xr.open_dataset(r"D:\Factor-Data\Tesina\Tesina\New folder\array_1.nc")
a = xr.open_dataset(r"D:\Factor-Data\Tesina\Tesina\New folder\array_1.nc")
a
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 10, y: 1431, x: 2101)
# Coordinates:
#   * time         (time) object '2015-08' '2016-08' ... '2023-08' '2024-08'
#   * x            (x) float32 -63.22 -63.22 -63.22 ... -62.65 -62.65 -62.65
#   * y            (y) float32 -40.66 -40.66 -40.66 ... -41.04 -41.04 -41.04
#     spatial_ref  int32 ...
# Data variables:
#     label        (time, y, x) float32 ...
# Attributes:
#     AREA_OR_POINT:           Area
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1
#     _FillValue:              -32768
#     scale_factor:            1.0
#     add_offset:              0.0

# %%
b = xr.open_dataset(r"D:\Factor-Data\Tesina\Tesina\New folder\array_2.nc")
b
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 10, y: 1431, x: 2102)
# Coordinates:
#   * time         (time) object '2015-08' '2016-08' ... '2023-08' '2024-08'
#   * x            (x) float32 -62.65 -62.65 -62.65 ... -62.09 -62.09 -62.09
#   * y            (y) float32 -40.66 -40.66 -40.66 ... -41.04 -41.04 -41.04
#     spatial_ref  int32 ...
# Data variables:
#     label        (time, y, x) float32 ...
# Attributes:
#     AREA_OR_POINT:           Area
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1
#     _FillValue:              -32768
#     scale_factor:            1.0
#     add_offset:              0.0

# %%
xr.combine_by_coords([a,b])
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 10, y: 1431, x: 4203)
# Coordinates:
#   * time         (time) object '2015-08' '2016-08' ... '2023-08' '2024-08'
#   * x            (x) float32 -63.22 -63.22 -63.22 ... -62.09 -62.09 -62.09
#   * y            (y) float32 -40.66 -40.66 -40.66 ... -41.04 -41.04 -41.04
#     spatial_ref  int32 0
# Data variables:
#     label        (time, y, x) float32 4.0 4.0 4.0 4.0 4.0 ... nan nan nan nan
# Attributes:
#     AREA_OR_POINT:           Area
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1
#     _FillValue:              -32768
#     scale_factor:            1.0
#     add_offset:              0.0
